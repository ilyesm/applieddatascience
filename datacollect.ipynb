# %%
df = px.data.stocks()
fig = px.line(data, x="Date", y='TSLA',
    hover_data={"Date": "|%B %d, %Y"},
    title='TSLA & AAPL Stock Price')

fig.add_scatter(x=data.Date, y=data.AAPL, mode='lines', name='AAPL')

fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")

fig.update_xaxes(rangeslider_visible=True)

fig.show()
